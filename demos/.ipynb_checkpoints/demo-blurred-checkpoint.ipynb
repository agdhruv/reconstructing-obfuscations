# %%
# imports
from tensorflow.keras.models import Model, load_model
from skimage.measure import compare_ssim as ssim
import pickle
from tensorflow.keras import backend as K
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# perceptual loss

from tensorflow.keras.applications.vgg16 import VGG16
def perceptual_loss(y_true, y_pred):
    vgg = VGG16(include_top=False, weights='imagenet', input_shape=(256,256,3))
    loss_model = Model(inputs=vgg.input, outputs=vgg.get_layer('block3_conv3').output)
    loss_model.trainable = False
    return K.mean(K.square(loss_model(y_true) - loss_model(y_pred)))

# %% [markdown]
# # Blurred - 2.5

# %%
# load validation dataset

pickle_in = open('../demo_datasets/blurred-2.5.pickle', 'rb')
X1 = pickle.load(pickle_in)
X1 = np.array(X1)

pickle_in1 = open('../demo_datasets/original-(unobfuscated).pickle', 'rb')
y1 = pickle.load(pickle_in1)
y1 = np.array(y1)

# %%
# load custom dataset

pickle_in = open('../demo_datasets/blurred-2.5-authors.pickle', 'rb')
X2 = pickle.load(pickle_in)
X2 = np.array(X2)

pickle_in1 = open('../demo_datasets/original-(unobfuscated)-authors.pickle', 'rb')
y2 = pickle.load(pickle_in1)
y2 = np.array(y2)

# %%
X_test = np.concatenate((X1, X2))
y_test = np.concatenate((y1, y2))

# %%
for i in range(14):
    plt.imshow(X_test[i])
    plt.show()
    plt.imshow(y_test[i])
    plt.show()

# %%
# load pre-trained model
autoencoder = load_model('../trained_models/2.5_blurred-1556714465.hd5', custom_objects={'perceptual_loss':perceptual_loss})

# %%
# choose image
i = 11

original = y_test[i]
obfuscated = X_test[i]
predicted = autoencoder.predict(np.array([X_test[i]]))

print("Obfuscated")
plt.axis('off')
plt.imshow(obfuscated)
plt.show()

print("Reconstructed")
plt.axis('off')
plt.imshow(predicted[0])
plt.show()

print("Original")
plt.axis('off')
plt.imshow(original)
plt.show()
# Out:
# Obfuscated
# Reconstructed
# Original

# %%
# Evaluation
ssim_value = ssim(obfuscated, original, multichannel=True) # b/w obfuscated and original
print(ssim_value)
# Out:
# 0.848630430907583

# %%
# Evaluation
ssim_value = ssim(np.array(predicted[0], dtype='float'), original, multichannel=True) # b/w reconstructed and original
print(ssim_value)
# Out:
# 0.8659243413920473

# %% [markdown]
# # Blurred - 4

# %%
# load validation dataset

pickle_in = open('../demo_datasets/blurred-4.pickle', 'rb')
X1 = pickle.load(pickle_in)
X1 = np.array(X1)

pickle_in1 = open('../demo_datasets/original-(unobfuscated).pickle', 'rb')
y1 = pickle.load(pickle_in1)
y1 = np.array(y1)

# %%
# load custom dataset

pickle_in = open('../demo_datasets/blurred-4-authors.pickle', 'rb')
X2 = pickle.load(pickle_in)
X2 = np.array(X2)

pickle_in1 = open('../demo_datasets/original-(unobfuscated)-authors.pickle', 'rb')
y2 = pickle.load(pickle_in1)
y2 = np.array(y2)

# %%
X_test = np.concatenate((X1, X2))
y_test = np.concatenate((y1, y2))

# %%
for i in range(14):
    plt.imshow(X_test[i])
    plt.show()
    plt.imshow(y_test[i])
    plt.show()

# %%
# load pre-trained model
autoencoder = load_model('../trained_models/4_blurred-1556739098.hd5', custom_objects={'perceptual_loss':perceptual_loss})

# %%
# choose image
i = 9

original = y_test[i]
obfuscated = X_test[i]
predicted = autoencoder.predict(np.array([X_test[i]]))

print("Obfuscated")
plt.axis('off')
plt.imshow(obfuscated)
plt.show()

print("Reconstructed")
plt.axis('off')
plt.imshow(predicted[0])
plt.show()

print("Original")
plt.axis('off')
plt.imshow(original)
plt.show()

# %%
# Evaluation
ssim_value = ssim(obfuscated, original, multichannel=True) # b/w obfuscated and original
print(ssim_value)
# Out:
# 0.6370918555734595

# %%
# Evaluation
ssim_value = ssim(np.array(predicted[0], dtype='float'), original, multichannel=True) # b/w reconstructed and original
print(ssim_value)
# Out:
# 0.728335575148695

# %% [markdown]
# # Blurred - 4 (MSE)

# %%
# load pre-trained model
autoencoder = load_model('../trained_models/4-mse_blurred-1556795381.hd5')

# %%
# choose image
i = 7

original = y_test[i]
obfuscated = X_test[i]
predicted = autoencoder.predict(np.array([X_test[i]]))

print("Obfuscated")
plt.axis('off')
plt.imshow(obfuscated)
plt.show()

print("Reconstructed")
plt.axis('off')
plt.imshow(predicted[0])
plt.show()

print("Original")
plt.axis('off')
plt.imshow(original)
plt.show()
# Out:
# Obfuscated
# Reconstructed
# Original

# %%
# Evaluation
ssim_value = ssim(obfuscated, original, multichannel=True) # b/w obfuscated and original
print(ssim_value)
# Out:
# 0.6370918555734595

# %%
# Evaluation
ssim_value = ssim(np.array(predicted[0], dtype='float'), original, multichannel=True) # b/w reconstructed and original
print(ssim_value)
# Out:
# 0.7525277671945462
